# %% [markdown]
# <a href="https://colab.research.google.com/github/jobsiggang/2026_AI_Datascience/blob/main/2026_%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EC%84%9D%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8_%ED%95%99%EC%83%9D%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #데이터 분석프로젝트

# %% [markdown]
# ## 학번 _ 이름 :

# %%
# 내 드라이브에 업로드=> 내 드라이브연결 => 파일 경로 복사 할 것
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install koreanize-matplotlib -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 65.7 MB/s eta 0:00:00

# %%
import koreanize_matplotlib
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 데이터 읽기
# save_path='/content/drive/국민건강보험공단_치매의료이용률.CSV'
save_path='자신의 파일 경로 붙여넣기'
df=pd.read_csv(save_path,encoding='cp949') # 또는 enconding='utf-8'
df
# 이후 코드를 추가하여 작성하세요~

# %% [markdown]
# 1)데이터를 선택한 이유,2)데이터설명 데이터의 특징,3) 데이터의 인사이트 4)활용방안 등을 다음 줄에 작성하세요

# %% [markdown]
# 1)데이터를 선택한 이유
#
# *   항목 추가
# *   항목 추가
#
#
# 2)데이터설명 데이터의 특징
#
#
# *   항목 추가
# *   항목 추가
#
#
# 3)데이터의 인사이트
#
#
# *   항목 추가
# *   항목 추가
#
#
# 4)활용방안
#
# *   항목 추가
# *   항목 추가
