# %% [markdown]
# <a href="https://colab.research.google.com/github/jobsiggang/2026_AI_Datascience/blob/main/2026kerisdata2~3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install koreanize-matplotlib -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 25.9 MB/s eta 0:00:00

# %% [markdown]
# # 데이터 통계량 확인과 결측치 처리

# %%
# https://data.kma.go.kr접속 [기후통계분석] > [조건별 통계]
import pandas as pd
df_wind = pd.read_csv('https://raw.githubusercontent.com/jobsiggang/2026_AI_Datascience/refs/heads/main/ulleongdo_wind.csv',encoding='CP949',index_col=0)
df_wind.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4016 entries, 115 to 115
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   지점명            4016 non-null   object
#  1   일시             4016 non-null   object
#  2   평균풍속(m/s)      4012 non-null   float64
#  3   최대풍속(m/s)      4014 non-null   float64
#  4   최대풍속풍향(deg)    4015 non-null   float64
#  5   	최대풍속시각        4015 non-null   object
#  6   최대순간풍속(m/s)    4014 non-null   float64
#  7   최대순간풍속풍향(deg)  4015 non-null   float64
#  8   	최대순간풍속시각      4015 non-null   object
# dtypes: float64(5), object(4)
# memory usage: 313.8+ KB

# %%
# 결측치 확인
import pandas as pd
df_wind = pd.read_csv('https://raw.githubusercontent.com/jobsiggang/2026_AI_Datascience/refs/heads/main/ulleongdo_wind.csv',encoding='CP949',index_col=0)
df_wind.isna().sum() #결측치의 개수 확인
# Out:
# 지점명              0
# 일시               0
# 평균풍속(m/s)        4
# 최대풍속(m/s)        2
# 최대풍속풍향(deg)      1
# \t최대풍속시각         1
# 최대순간풍속(m/s)      2
# 최대순간풍속풍향(deg)    1
# \t최대순간풍속시각       1
# dtype: int64

# %%
#평균풍속 결측치 데이터 확인
df_wind[df_wind["평균풍속(m/s)"].isna()]
# Out:
#       지점명          일시  평균풍속(m/s)  최대풍속(m/s)  최대풍속풍향(deg) \t최대풍속시각  \
# 지점번호
# 115   울릉도  2015-03-22        NaN       11.6        340.0    06:38
# 115   울릉도  2015-04-01        NaN       12.1         50.0    10:27
# 115   울릉도  2019-04-18        NaN       11.7        230.0    22:50
# 115   울릉도  2025-12-27        NaN        NaN          NaN      NaN
#
#       최대순간풍속(m/s)  최대순간풍속풍향(deg) \t최대순간풍속시각
# 지점번호
# 115          19.1          340.0      06:29
# 115          20.9           70.0      10:22
# 115          16.5          200.0      12:18
# 115           NaN            NaN        NaN

# %%
#데이터 통계 확인
df_wind.describe()
# Out:
#          평균풍속(m/s)    최대풍속(m/s)  최대풍속풍향(deg)  최대순간풍속(m/s)  최대순간풍속풍향(deg)
# count  4016.000000  4016.000000  4016.000000  4016.000000    4016.000000
# mean      3.887886     7.828331   168.250470    13.205049     172.004952
# std       1.836362     3.013254   104.421911     5.098674     103.899165
# min       0.700000     1.900000     3.887886     3.500000       3.887886
# 25%       2.500000     5.500000    50.000000     9.300000      50.000000
# 50%       3.500000     7.500000   230.000000    12.800000     200.000000
# 75%       4.900000     9.700000   250.000000    16.700000     250.000000
# max      14.900000    26.000000   360.000000    43.400000     360.000000

# %%
#결측치 처리 1
import pandas as pd
df_wind = pd.read_csv('https://raw.githubusercontent.com/jobsiggang/2026_AI_Datascience/refs/heads/main/ulleongdo_wind.csv',encoding='CP949',index_col=0)

# 결측값(NaN)을 0으로 채움
df_wind.fillna(0, inplace=True)
# 평균풍속(m/s)이 0인 행을 선택하여 출력
df_wind[df_wind['평균풍속(m/s)'] == 0.0]
# Out:
#       지점명          일시  평균풍속(m/s)  최대풍속(m/s)  최대풍속풍향(deg) \t최대풍속시각  \
# 지점번호
# 115   울릉도  2015-03-22        0.0       11.6        340.0    06:38
# 115   울릉도  2015-04-01        0.0       12.1         50.0    10:27
# 115   울릉도  2019-04-18        0.0       11.7        230.0    22:50
# 115   울릉도  2025-12-27        0.0        0.0          0.0        0
#
#       최대순간풍속(m/s)  최대순간풍속풍향(deg) \t최대순간풍속시각
# 지점번호
# 115          19.1          340.0      06:29
# 115          20.9           70.0      10:22
# 115          16.5          200.0      12:18
# 115           0.0            0.0          0

# %%
#결측치 처리 2
import pandas as pd
df_wind = pd.read_csv('https://raw.githubusercontent.com/jobsiggang/2026_AI_Datascience/refs/heads/main/ulleongdo_wind.csv',encoding='CP949',index_col=0)
# 평균풍속(m/s)이 0인 행을 선택하여 출력
df_wind[df_wind['평균풍속(m/s)'] == 0.0]
# '평균풍속(m/s)' 열의 평균값으로 결측값(NaN)을 채움
# inplace=True로 설정하여 원본 DataFrame에서 직접 수정
df_wind.fillna(df_wind['평균풍속(m/s)'].mean(), inplace=True)

# '일시' 열이 '2019-04-18'인 행을 선택하여 출력
df_wind[df_wind['일시'] == '2019-04-18']
# Out:
#       지점명          일시  평균풍속(m/s)  최대풍속(m/s)  최대풍속풍향(deg) \t최대풍속시각  \
# 지점번호
# 115   울릉도  2019-04-18   3.887886       11.7        230.0    22:50
#
#       최대순간풍속(m/s)  최대순간풍속풍향(deg) \t최대순간풍속시각
# 지점번호
# 115          16.5          200.0      12:18

# %%
#결측치 삭제
import pandas as pd
df_wind = pd.read_csv('https://raw.githubusercontent.com/jobsiggang/2026_AI_Datascience/refs/heads/main/ulleongdo_wind.csv',encoding='CP949',index_col=0)
# 결측값(NaN)이 포함된 행을 모두 삭제
# axis=0은 행(row) 단위로 동작함을 의미하며,
# how="any"는 하나라도 결측값이 있는 행을 삭제하는 설정
# inplace=True는 원본 DataFrame에서 바로 수정이 이루어지도록 함
df_wind.dropna(axis=0, how="any", inplace=True)
df_wind[ df_wind['일시'] =='2019-04-18']
# Out:
# Empty DataFrame
# Columns: [지점명, 일시, 평균풍속(m/s), 최대풍속(m/s), 최대풍속풍향(deg), 	최대풍속시각, 최대순간풍속(m/s), 최대순간풍속풍향(deg), 	최대순간풍속시각]
# Index: []

# %% [markdown]
# # 데이터 이상치 처리

# %%
# 캐글에서 Korea's Apple로 검색  https://www.kaggle.com/datasets/chochochosam/analysis-of-koreas-apples
import pandas as pd
df_Hongro = pd.read_csv('https://raw.githubusercontent.com/jobsiggang/2026_AI_Datascience/refs/heads/main/Hongro.csv')
df_Hongro.head()
# Out:
#     지역        수확일자  과중(g)  종경(mm)  횡경(mm)  L/D 비율   경도1   경도2  경도평균  \
# 0   포천  2022-09-07  268.0    79.9    86.3    0.92  40.5  39.0  39.8
# 1   화성  2022-09-02  358.3    92.8    94.5    0.98  36.4  38.2  37.3
# 2   완주  2022-09-02  258.9    78.0    83.2    0.94  38.2  37.6  37.9
# 3  완주2  2022-09-01  291.1    79.3    87.1    0.91  38.9  37.8  38.4
# 4   군위  2021-08-26  265.5    78.9    85.4    0.92  55.8  56.1  56.0
#
#    당도(˚Brix)  산도(%)  착색(Hunter L)  착색(Hunter a)  착색(Hunter b)
# 0       14.1   0.21          39.1          28.7          14.6
# 1       12.5   0.24          54.1          14.4          20.1
# 2       13.4   0.26          58.3          10.0          21.3
# 3       13.4   0.25          58.3           9.4          20.1
# 4       13.4   0.22          53.2          16.6          19.5

# %%
df_Hongro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   지역            50 non-null     object
#  1   수확일자          50 non-null     object
#  2   과중(g)         50 non-null     float64
#  3   종경(mm)        50 non-null     float64
#  4   횡경(mm)        50 non-null     float64
#  5   L/D 비율        50 non-null     float64
#  6   경도1           50 non-null     float64
#  7   경도2           50 non-null     float64
#  8   경도평균          50 non-null     float64
#  9   당도(˚Brix)     50 non-null     float64
#  10  산도(%)         50 non-null     float64
#  11  착색(Hunter L)  50 non-null     float64
#  12  착색(Hunter a)  50 non-null     float64
#  13  착색(Hunter b)  50 non-null     float64
# dtypes: float64(12), object(2)
# memory usage: 5.6+ KB

# %%
# 통계값 확인
df_Hongro.describe()
# Out:
#             과중(g)     종경(mm)      횡경(mm)     L/D 비율        경도1        경도2  \
# count   50.000000  50.000000   50.000000  50.000000  50.000000  50.000000
# mean   278.200000  78.766000   85.038000   0.908800  44.796000  44.394000
# std     57.931194  13.422759   13.675733   0.136182  12.148233  11.829286
# min    134.300000   0.000000    0.000000   0.000000   0.000000   0.000000
# 25%    248.650000  76.025000   83.650000   0.902500  37.300000  37.625000
# 50%    270.650000  79.650000   86.500000   0.920000  40.600000  40.150000
# 75%    303.100000  83.600000   90.350000   0.950000  56.650000  56.450000
# max    454.200000  99.800000  103.600000   1.040000  66.500000  63.300000
#
#             경도평균  당도(˚Brix)      산도(%)  착색(Hunter L)  착색(Hunter a)  \
# count  50.000000  50.000000  50.000000     50.000000     50.000000
# mean   44.594000  13.762000   0.245600     54.394000     18.584000
# std    11.867765   1.154917   0.057611      6.183302      7.201257
# min     0.000000  11.000000   0.000000     39.100000      3.100000
# 25%    37.450000  13.225000   0.212500     51.175000     14.800000
# 50%    40.350000  13.800000   0.240000     54.400000     18.550000
# 75%    56.650000  14.575000   0.280000     58.200000     23.600000
# max    62.900000  16.100000   0.370000     70.400000     36.000000
#
#        착색(Hunter b)
# count      50.00000
# mean       22.29000
# std         4.80804
# min        14.60000
# 25%        18.90000
# 50%        20.95000
# 75%        26.52500
# max        34.20000

# %%
df_Hongro.columns
# Out:
# Index(['지역', '수확일자', '과중(g)', '종경(mm)', '횡경(mm)', 'L/D 비율', '경도1', '경도2',
#        '경도평균', '당도(˚Brix)', '산도(%)', '착색(Hunter L)', '착색(Hunter a)',
#        '착색(Hunter b)'],
#       dtype='object')

# %%
#박스플롯으로 이상치 확인
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(data=df_Hongro[[  '종경(mm)', '횡경(mm)']] )
plt.show()

# %% [markdown]
# #데이터 정규화

# %%
import pandas as pd
df_heavymetal = pd.read_csv('https://raw.githubusercontent.com/jobsiggang/2026_AI_Datascience/refs/heads/main/heavymetal.csv',encoding='cp949')
df_heavymetal.head()
# Out:
#            연월  납(마이크로그램 퍼 세제곱미터)   카드뮴(마이크로그램 퍼 세제곱미터)   크롬(마이크로그램 퍼 세제곱미터)   \
# 0  2025-01-01             0.09149               0.00469              0.00263
# 1  2025-02-01             0.07537               0.00636              0.00135
# 2  2025-03-01             0.04610               0.00195              0.00266
# 3  2025-04-01             0.05360               0.00484              0.00247
# 4  2025-05-01             0.03667               0.00176              0.00243
#
#    구리(마이크로그램 퍼 세제곱미터)   망간(마이크로그램 퍼 세제곱미터)   철(마이크로그램 퍼 세제곱미터)   \
# 0              0.02657              0.03747             0.52214
# 1              0.01684              0.02285             0.27262
# 2              0.01513              0.03403             0.58333
# 3              0.02526              0.04653             0.74231
# 4              0.02064              0.03679             0.49613
#
#    니켈(마이크로그램 퍼 세제곱미터)   비소(마이크로그램 퍼 세제곱미터)   베릴륨(마이크로그램 퍼 세제곱미터)   \
# 0              0.00665              0.01476                     0
# 1              0.00294              0.03289                     0
# 2              0.00862              0.00873                     0
# 3              0.00443              0.01317                     0
# 4              0.00423              0.00495                     0
#
#    알루미늄(마이크로그램 퍼 세제곱미터)   칼슘(마이크로그램 퍼 세제곱미터)   마그네슘(마이크로그램 퍼 세제곱미터)
# 0                0.15720              0.45158                0.11938
# 1                0.07042              0.20955                0.07750
# 2                0.23108              0.70332                0.18003
# 3                0.29929              0.77904                0.36815
# 4                0.20874              0.45046                0.18034

# %%
df_heavymetal.describe()
# Out:
#        납(마이크로그램 퍼 세제곱미터)   카드뮴(마이크로그램 퍼 세제곱미터)   크롬(마이크로그램 퍼 세제곱미터)   \
# count           12.000000             12.000000            12.000000
# mean             0.078455              0.004550             0.002355
# std              0.034654              0.002204             0.001059
# min              0.036670              0.001760             0.000050
# 25%              0.052525              0.003115             0.002027
# 50%              0.070375              0.004105             0.002450
# 75%              0.097525              0.005220             0.002638
# max              0.153300              0.008570             0.004240
#
#        구리(마이크로그램 퍼 세제곱미터)   망간(마이크로그램 퍼 세제곱미터)   철(마이크로그램 퍼 세제곱미터)   \
# count            12.000000            12.000000           12.000000
# mean              0.024503             0.040545            0.563292
# std               0.007674             0.015599            0.187481
# min               0.014880             0.013640            0.272620
# 25%               0.019690             0.034120            0.463048
# 50%               0.024755             0.037130            0.522815
# 75%               0.027465             0.049010            0.668795
# max               0.041170             0.067450            0.927460
#
#        니켈(마이크로그램 퍼 세제곱미터)   비소(마이크로그램 퍼 세제곱미터)   베릴륨(마이크로그램 퍼 세제곱미터)   \
# count            12.000000            12.000000                  12.0
# mean              0.005589             0.017866                   0.0
# std               0.002305             0.009518                   0.0
# min               0.001370             0.004950                   0.0
# 25%               0.004380             0.012475                   0.0
# 50%               0.005650             0.013965                   0.0
# 75%               0.006727             0.027463                   0.0
# max               0.009730             0.032890                   0.0
#
#        알루미늄(마이크로그램 퍼 세제곱미터)   칼슘(마이크로그램 퍼 세제곱미터)   마그네슘(마이크로그램 퍼 세제곱미터)
# count              12.000000            12.000000              12.000000
# mean                0.184180             0.486580               0.167209
# std                 0.094823             0.197605               0.079251
# min                 0.067670             0.209550               0.077500
# 25%                 0.103325             0.323238               0.116553
# 50%                 0.182970             0.451020               0.156415
# 75%                 0.251455             0.660018               0.185982
# max                 0.332930             0.779040               0.368150

# %%
#칼럼명 변경
df_heavymetal.columns = ['연월', '납', '카드뮴', '크롬', '구리', '망간', '철', '니켈', '비소', '베릴륨', '알루미늄', '칼슘', '마그네슘']

# %%
# 칼럼 확인
df_heavymetal.columns
# Out:
# Index(['연월', '납', '카드뮴', '크롬', '구리', '망간', '철', '니켈', '비소', '베릴륨', '알루미늄',
#        '칼슘', '마그네슘'],
#       dtype='object')

# %%
columns=['납', '카드뮴', '크롬', '구리', '망간', '철', '니켈', '비소', '베릴륨', '알루미늄',
       '칼슘', '마그네슘']
sns.boxplot(data=df_heavymetal[columns] )
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
# 최소-최대 정규화 (Min-Max Scaling) 수행
# 데이터를 0과 1 사이의 값으로 변환합니다.
scaler = MinMaxScaler()
# 선택된 컬럼에 Min-Max Scaling 적용
df_normalized = df_heavymetal.copy() # 원본 데이터프레임 복사
df_normalized[columns] = scaler.fit_transform(df_heavymetal[columns])

df_normalized.describe()
# Out:
#                납        카드뮴         크롬         구리         망간          철  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean    0.358270   0.409692   0.550119   0.366045   0.500000   0.443882
# std     0.297131   0.323674   0.252833   0.291891   0.289895   0.286300
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.135943   0.198972   0.471957   0.182959   0.380598   0.290800
# 50%     0.288991   0.344347   0.572792   0.375618   0.436536   0.382070
# 75%     0.521778   0.508076   0.617542   0.478699   0.657313   0.604995
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#               니켈         비소   베릴륨       알루미늄         칼슘       마그네슘
# count  12.000000  12.000000  12.0  12.000000  12.000000  12.000000
# mean    0.504685   0.462270   0.0   0.439229   0.486453   0.308650
# std     0.275769   0.340657   0.0   0.357471   0.346985   0.272669
# min     0.000000   0.000000   0.0   0.000000   0.000000   0.000000
# 25%     0.360048   0.269327   0.0   0.134415   0.199630   0.134363
# 50%     0.511962   0.322656   0.0   0.434668   0.424011   0.271512
# 75%     0.640849   0.805744   0.0   0.692849   0.791002   0.373241
# max     1.000000   1.000000   0.0   1.000000   1.000000   1.000000

# %%
#정규화 된 데이터 확인
sns.boxplot(data=df_normalized)
# Out:
# <Axes: >

# %% [markdown]
# # 데이터 속성간 관계

# %%
# 캐글에서 Korea's Apple로 검색  https://www.kaggle.com/datasets/chochochosam/analysis-of-koreas-apples
import pandas as pd
df_Hongro = pd.read_csv('https://raw.githubusercontent.com/jobsiggang/2026_AI_Datascience/refs/heads/main/Hongro.csv')
df_Hongro.head()
# Out:
#     지역        수확일자  과중(g)  종경(mm)  횡경(mm)  L/D 비율   경도1   경도2  경도평균  \
# 0   포천  2022-09-07  268.0    79.9    86.3    0.92  40.5  39.0  39.8
# 1   화성  2022-09-02  358.3    92.8    94.5    0.98  36.4  38.2  37.3
# 2   완주  2022-09-02  258.9    78.0    83.2    0.94  38.2  37.6  37.9
# 3  완주2  2022-09-01  291.1    79.3    87.1    0.91  38.9  37.8  38.4
# 4   군위  2021-08-26  265.5    78.9    85.4    0.92  55.8  56.1  56.0
#
#    당도(˚Brix)  산도(%)  착색(Hunter L)  착색(Hunter a)  착색(Hunter b)
# 0       14.1   0.21          39.1          28.7          14.6
# 1       12.5   0.24          54.1          14.4          20.1
# 2       13.4   0.26          58.3          10.0          21.3
# 3       13.4   0.25          58.3           9.4          20.1
# 4       13.4   0.22          53.2          16.6          19.5

# %%
df_Hongro.columns
# Out:
# Index(['지역', '수확일자', '과중(g)', '종경(mm)', '횡경(mm)', 'L/D 비율', '경도1', '경도2',
#        '경도평균', '당도(˚Brix)', '산도(%)', '착색(Hunter L)', '착색(Hunter a)',
#        '착색(Hunter b)'],
#       dtype='object')

# %%
# 당도와 상관관계를 있는 속성을 찾아보자
df_Hongro.corr(numeric_only=True)
# Out:
#                  과중(g)    종경(mm)    횡경(mm)    L/D 비율       경도1       경도2  \
# 과중(g)         1.000000  0.684035  0.631014  0.335179 -0.159280 -0.102035
# 종경(mm)        0.684035  1.000000  0.971810  0.905047  0.299778  0.328130
# 횡경(mm)        0.631014  0.971810  1.000000  0.896133  0.341931  0.383856
# L/D 비율        0.335179  0.905047  0.896133  1.000000  0.504302  0.501606
# 경도1          -0.159280  0.299778  0.341931  0.504302  1.000000  0.958272
# 경도2          -0.102035  0.328130  0.383856  0.501606  0.958272  1.000000
# 경도평균         -0.132326  0.317069  0.366259  0.508314  0.989872  0.989137
# 당도(˚Brix)     0.067585 -0.111735 -0.107385 -0.168203 -0.331963 -0.389049
# 산도(%)         0.026147  0.413641  0.471442  0.565082  0.575474  0.620683
# 착색(Hunter L) -0.193120 -0.167997 -0.198303 -0.086920 -0.134089 -0.211278
# 착색(Hunter a)  0.171039  0.061444  0.058353 -0.056645 -0.389674 -0.380943
# 착색(Hunter b) -0.171267 -0.184459 -0.181535 -0.148412 -0.392779 -0.466780
#
#                   경도평균  당도(˚Brix)     산도(%)  착색(Hunter L)  착색(Hunter a)  \
# 과중(g)        -0.132326   0.067585  0.026147     -0.193120      0.171039
# 종경(mm)        0.317069  -0.111735  0.413641     -0.167997      0.061444
# 횡경(mm)        0.366259  -0.107385  0.471442     -0.198303      0.058353
# L/D 비율        0.508314  -0.168203  0.565082     -0.086920     -0.056645
# 경도1           0.989872  -0.331963  0.575474     -0.134089     -0.389674
# 경도2           0.989137  -0.389049  0.620683     -0.211278     -0.380943
# 경도평균          1.000000  -0.364128  0.603836     -0.174550     -0.389033
# 당도(˚Brix)    -0.364128   1.000000 -0.415722      0.235708      0.185386
# 산도(%)         0.603836  -0.415722  1.000000      0.054636     -0.472166
# 착색(Hunter L) -0.174550   0.235708  0.054636      1.000000     -0.517283
# 착색(Hunter a) -0.389033   0.185386 -0.472166     -0.517283      1.000000
# 착색(Hunter b) -0.434404   0.348453 -0.124602      0.792091     -0.021967
#
#               착색(Hunter b)
# 과중(g)            -0.171267
# 종경(mm)           -0.184459
# 횡경(mm)           -0.181535
# L/D 비율           -0.148412
# 경도1              -0.392779
# 경도2              -0.466780
# 경도평균             -0.434404
# 당도(˚Brix)         0.348453
# 산도(%)            -0.124602
# 착색(Hunter L)      0.792091
# 착색(Hunter a)     -0.021967
# 착색(Hunter b)      1.000000

# %%
corr = df_Hongro.corr(numeric_only=True)
corr["당도(˚Brix)"]
# Out:
# 과중(g)           0.067585
# 종경(mm)         -0.111735
# 횡경(mm)         -0.107385
# L/D 비율         -0.168203
# 경도1            -0.331963
# 경도2            -0.389049
# 경도평균           -0.364128
# 당도(˚Brix)       1.000000
# 산도(%)          -0.415722
# 착색(Hunter L)    0.235708
# 착색(Hunter a)    0.185386
# 착색(Hunter b)    0.348453
# Name: 당도(˚Brix), dtype: float64

# %%
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # 데이터 시각화 분석
